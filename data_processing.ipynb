# %%
import pandas as pd

# %%
df = pd.read_csv('V_OCORRENCIA_AMPLA.csv', sep=";")
df
# Out:
#        Numero_da_Ocorrencia Numero_da_Ficha  \
# 0                     25043       202019110
# 1                     25081       0940/2013
# 2                     25503       202023366
# 3                     25623       202021754
# 4                     25624       202004387
# ...                     ...             ...
# 11768                 36306      2023466783
# 11769                 36346      2023211240
# 11770                 36348      2023242037
# 11771                 36349      2023261212
# 11772                 36486      2023420958
#
#                                   Operador_Padronizado  \
# 0                 CARAJÁS SERVIÇOS DE LOCAÇÃO LTDA EPF
# 1                                     TAP AIR PORTUGAL
# 2                                                 AZUL
# 3                         JOAO MAURICIO GOTTARDI LOPES
# 4                            JOSE LUIZ CUNHA RODRIGUES
# ...                                                ...
# ...

# %%
df_1 = df[['Operacao', 'Operador_Padronizado', 'Descricao_do_Tipo']]
df_1
# Out:
#                 Operacao                             Operador_Padronizado  \
# 0            Voo Privado             CARAJÁS SERVIÇOS DE LOCAÇÃO LTDA EPF
# 1            Voo Regular                                 TAP AIR PORTUGAL
# 2            Voo Regular                                             AZUL
# 3            Voo Privado                     JOAO MAURICIO GOTTARDI LOPES
# 4            Voo Privado                        JOSE LUIZ CUNHA RODRIGUES
# ...                  ...                                              ...
# 11768        Voo Privado                      AGROPASTORIL SAO PEDRO LTDA
# 11769        Voo Privado  GLOBAL ADMINISTRAÇÃO E SOLUÇÕES INTEGRADAS LTDA
# 11770  Operação Agrícola                   PLA & SILVA AVIACAO AGRIC.LTDA
# 11771        Voo Privado                           FERNANDO ANTONIO COSTA
# 11772   Voo Experimental                        JHONATA DO PRADO DE FARIA
#
#                                        Descricao_do_Tipo
# ...

# %%
df_1.query("Operacao in ('Voo Regular','Táxi Aéreo')", inplace=True)
df_1['Operacao']
# Out:
# C:\Users\albuquer\AppData\Local\Temp\ipykernel_4912\3634036786.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1.query("Operacao in ('Voo Regular','Táxi Aéreo')", inplace=True)
# 1        Voo Regular
# 2        Voo Regular
# 7         Táxi Aéreo
# 10       Voo Regular
# 14       Voo Regular
#             ...
# 11751    Voo Regular
# 11757    Voo Regular
# 11759    Voo Regular
# 11762    Voo Regular
# 11764    Voo Regular
# Name: Operacao, Length: 4644, dtype: object

# %%
df_1.to_csv("data_processing.csv")
